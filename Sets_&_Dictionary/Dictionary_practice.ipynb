# %% [markdown]
# # Dictionary

# %% [markdown]
# ### Create Dictionary

# %%
mydict = dict() 
mydict
# Out:
# {}

# %%
mydict = {}
mydict
# Out:
# {}

# %%
mydict = {1:'one' , 2:'two' , 3:'three'} # dictionary with integer keys
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = {'A':'one' , 'B':'two' , 'C':'three'} # dictionary with character keys 
mydict
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydict = dict({1:'one' , 2:'two' , 3:'three'}) # Create dictionary using dict() 
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = {1:'one' , 'A':'two' , 3:'three'} # dictionary with mixed keys 
mydict
# Out:
# {1: 'one', 'A': 'two', 3: 'three'}

# %%
mydict.keys()
# Out:
# dict_keys([1, 'A', 3])

# %%
mydict.values()
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict.items()
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
mydict = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria']}  
mydict
# Out:
# {1: 'one', 2: 'two', 'A': ['asif', 'john', 'Maria']}

# %%
mydict = {1:'one' , 2:'two' , 'A':['asif' , 'john' , 'Maria'], 'B':('Bat' , 'cat','hat') }
mydict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': ['asif', 'john', 'Maria'],
#  'B': ('Bat', 'cat', 'hat')}

# %%
mydict = {1:'one' , 2:'two' , 'A':{'Name':'asif' , 'Age' :20}, 'B':('Bat' , 'cat','hat') }
mydict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'asif', 'Age': 20},
#  'B': ('Bat', 'cat', 'hat')}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
mydict3 = dict.fromkeys(keys) # Create a dictionary from a sequence of keys 
mydict3
# Out:
# {'d': None, 'c': None, 'a': None, 'b': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = 10 
mydict3 = dict.fromkeys(keys , value)  
mydict3
# Out:
# {'d': 10, 'c': 10, 'a': 10, 'b': 10}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = [10,20,30] 
mydict3 = dict.fromkeys(keys , value) 
mydict3
# Out:
# {'d': [10, 20, 30], 'c': [10, 20, 30], 'a': [10, 20, 30], 'b': [10, 20, 30]}

# %%
value.append(40) 
mydict3
# Out:
# {'d': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40],
#  'a': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40]}

# %% [markdown]
# ### Accessing Items

# %%
mydict = {1:'one' , 2:'two' , 3:'three' , 4:'four'} 
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1]
# Out:
# 'one'

# %%
mydict.get(1)
# Out:
# 'one'

# %%
mydict1 = {'Name':'Aaru' , 'ID': 74123 , 'DOB': 1991 , 'job' :'Analyst'} 
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 74123, 'DOB': 1991, 'job': 'Analyst'}

# %%
mydict1['Name']
# Out:
# 'Aaru'

# %%
mydict1.get('job')
# Out:
# 'Analyst'

# %% [markdown]
# ### Add, Remove & Change Items

# %%
 
mydict1 = {'Name':'Aaru' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'} 
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1['DOB'] = 1992 # Changing Dictionary Items 
mydict1['Address'] = 'Delhi' 
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1992, 'Address': 'Delhi'}

# %%
dict1 = {'DOB':1995} 
mydict1.update(dict1) 
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1['Job'] = 'Analyst' # Adding items in the dictionary 
mydict1
# Out:
# {'Name': 'Aaru',
#  'ID': 12345,
#  'DOB': 1995,
#  'Address': 'Delhi',
#  'Job': 'Analyst'}

# %%
mydict1.pop('Job') # Removing items in the dictionary using Pop method 
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1.popitem()
# Out:
# ('Address', 'Delhi')

# %%
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1995}

# %%
del[mydict1['ID']] # Removing item using del method 
mydict1
# Out:
# {'Name': 'Aaru', 'DOB': 1995}

# %%
mydict1.clear() # Delete all items of the dictionary using clear method 
mydict1
# Out:
# {}

# %%
del mydict1 # Delete the dictionary object 
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 del mydict1 # Delete the dictionary object
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# ### Copy Dictionary

# %%
mydict = {'Name':'Aaru' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'} 
mydict
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1 = mydict 
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
id(mydict) , id(mydict1)
# Out:
# (2743190733568, 2743190733568)

# %%
mydict2 = mydict.copy()
mydict2
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
id(mydict2)
# Out:
# 2743190645696

# %%
mydict['Address'] = 'Mumbai' 
mydict
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
print(mydict1)
print(mydict2)
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %% [markdown]
# ### Loop through a Dictionary

# %%
mydict1 = {'Name':'Aaru' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki' , 'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Aaru',
#  'ID': 12345,
#  'DOB': 1991,
#  'Address': 'Hilsinki',
#  'Job': 'Analyst'}

# %%
for i in mydict1: 
   print(i , ':' , mydict1[i])
# Out:
# Name : Aaru
# ID : 12345
# DOB : 1991
# Address : Hilsinki
# Job : Analyst

# %%
for i in mydict1: 
    print(mydict1[i])
# Out:
# Aaru
# 12345
# 1991
# Hilsinki
# Analyst

# %% [markdown]
# ### Dictionary Membership

# %%
mydict1 = {'Name':'Aaru' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
'Name' in mydict1
# Out:
# True

# %%
'Asif' in mydict1
# Out:
# False

# %%
'ID' in mydict1
# Out:
# True

# %%
'Address' in mydict1
# Out:
# False

# %% [markdown]
# # All / Any
# The all() method returns:
#  - True - If all all keys of the dictionary are true
#  - False - If any key of the dictionary is false
#
#    The any() function returns True if any key of the dictionary is True. If not, any() returns False.

# %%
mydict1 = {'Name':'Aaru' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Aaru', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
all(mydict1) # Will Return false as one value is false (Value 0)
# Out:
# True

# %% [markdown]
# # Python Operators

# %% [markdown]
# ## operator
# - 1- ARITHMETIC OPERATOR ( + , -, *, /, %, %%, **, ^
# - 2- ASSIGNMEN OPERATOR (=)
# - 3- RELATIONAL OPERATOR
# - 4- LOGICAL OPERATOR
# - 5- UNARY OPERATOR

# %%
x1, y1 = 10, 5

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1 / y1
# Out:
# 2.0

# %%
x1 // y1
# Out:
# 2

# %%
x1 % y1
# Out:
# 0

# %%
x1 ** y1
# Out:
# 100000

# %%
3 ** 4
# Out:
# 81

# %% [markdown]
# ### 1 assignment operator

# %%
x = 2
x
# Out:
# 2

# %%
x + 2
# Out:
# 4

# %%
x += 2
x
# Out:
# 4

# %%
x *= 2
x
# Out:
# 8

# %%
x /= 2
x
# Out:
# 4.0

# %%
x //= 2
x
# Out:
# 2.0

# %%
y = 12
y //= 2
y
# Out:
# 6

# %% [markdown]
# ### 2 Unary Operator

# %%
n = 7

# %%
m = -(n)
m
# Out:
# -7

# %% [markdown]
# ### 3 relational operator  ( >, <, <=, >=)

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
b = 7

# %%
a
# Out:
# 5

# %%
a != b
# Out:
# True

# %% [markdown]
# ### 4 logical operator (and, or, not)

# %%
a = 5
b = 4

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
b = 5

# %%
a == b
# Out:
# True

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 or b < 5
# Out:
# True

# %%
a>8 or b<2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %% [markdown]
# ### python operators we are completed

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
0x9
# Out:
# 9

# %%
0xa
# Out:
# 10

# %%
0xb
# Out:
# 11

# %%
0xc
# Out:
# 12

# %%
0xd
# Out:
# 13

# %%
0xe
# Out:
# 14

# %%
0xf
# Out:
# 15

# %%
0xg
# Out:
#   Cell In[55], line 1
#     0xg
#      ^
# SyntaxError: invalid hexadecimal literal

# %% [markdown]
# ## 6 BITWISE OPERATOR
#
# - COMPLEMENT ( ~ ) ||
# - AND ( & )  ||
# - OR ( | ) ||
# - XOR ( ^ ) ||
# - LEFT SHIFT ( << ) ||
# - RIGHT SHIFT ( >> )

# %%
print(bin(12))
print(bin(13))
# Out:
# 0b1100
# 0b1101

# %%
~12
# Out:
# -13

# %%
~15
# Out:
# -16

# %%
~10
# Out:
# -11

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12 ^ 13
# Out:
# 1

# %%
35^40
# Out:
# 11

# %% [markdown]
# - left shift -- we gain the bit <<
# - right shift -- we loose the bit >>

# %%
12 << 2
# Out:
# 48

# %%
12<<1
# Out:
# 24

# %%
12 >> 1
# Out:
# 6

# %%
12>> 2
# Out:
# 3

# %% [markdown]
# #### bitwise we are completed

# %% [markdown]
# # Swap 2 variable

# %%
a , b = 5, 6

# %%
print(a)
print(b)
# Out:
# 5
# 6

# %%
temp = a
a = b
b = temp

# %%
print(a)
print(b)
# Out:
# 6
# 5

# %%
a = a + b # 5+6 = 11
b = a - b # 11-6 = 5
a = a - b

# %%
print(a)
print(b)
# Out:
# 5
# 6

# %%
a = a ^ b
b = a ^ b
a = a ^ b

# %%
print(a)
print(b)
# Out:
# 6
# 5

# %%
a,b = b,a

# %%
print(a)
print(b)
# Out:
# 5
# 6
